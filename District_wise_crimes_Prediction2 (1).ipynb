# %% [markdown]
# ## Problem Statement --)To predict the No. of crimes happen in the year 2001 to 2012 in different District

# %% [markdown]
# ##### IPC = The Indian Penal Code (IPC) is the official criminal code of India.It is a comprehensive code intended to cover all             substantive aspects of criminal law.
# ##### It is applicable to all the citizens of India. The IPC has been amended numerous times since then and is now supplemented by various other criminal provisions. At present, the IPC is divided into 23 chapters and contains 511 sections in total.

# %% [markdown]
# # Important Libraries:

# %%
import numpy as np
import pandas as pd
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Read Dataset

# %%
data=pd.read_csv(r"C:\Users\Sharwari\Documents\01_District_wise_crimes_committed_IPC_2001_2012.csv")

# %%
data=data.rename(columns={"TOTAL IPC CRIMES":"TOTAL_IPC_CRIMES","ATTEMPT TO MURDER":"ATTEMPT_TO_MURDER","CULPABLE HOMICIDE NOT AMOUNTING TO MURDER":"CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER","CUSTODIAL RAPE":"CUSTODIAL_RAPE","OTHER RAPE":"OTHER_RAPE","KIDNAPPING & ABDUCTION":"KIDNAPPING_and_ABDUCTION","KIDNAPPING AND ABDUCTION OF WOMEN AND GIRLS":"KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS","KIDNAPPING AND ABDUCTION OF OTHERS":"KIDNAPPING_AND_ABDUCTION_OF_OTHERS","STATE/UT":"STATE_or_UT","PREPARATION AND ASSEMBLY FOR DACOITY":"PREPARATION_AND_ASSEMBLY_FOR_DACOITY","AUTO THEFT":"AUTO_THEFT","OTHER THEFT":"OTHER_THEFT","CRIMINAL BREACH OF TRUST":"CRIMINAL_BREACH_OF_TRUST","HURT/GREVIOUS HURT":"HURT_or_GREVIOUS_HURT","DOWRY DEATHS":"DOWRY_DEATHS","ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY":"ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY","INSULT TO MODESTY OF WOMEN":"INSULT_TO_MODESTY_OF_WOMEN","CRUELTY BY HUSBAND OR HIS RELATIVES":"CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES","IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES":"IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES","CAUSING DEATH BY NEGLIGENCE":"CAUSING_DEATH_BY_NEGLIGENCE","OTHER IPC CRIMES":"OTHER_IPC_CRIMES"})

# %%
data.head()
# Out:
#    index     STATE_or_UT       DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0      0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1      1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2      2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3      3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4      4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER_RAPE  ...  ARSON  HURT_or_GREVIOUS_HURT  DOWRY_DEATHS  \
# 0          50  ...     30                   1131            16
# 1          23  ...     69                   1543             7
# 2          27  ...     38                   2088            14
# 3          20  ...     23                    795            17
# 4          23  ...     41                   1244            12
#
#    ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY  \
# 0                                                149
# 1                                                118
# 2                                                112
# 3                                                126
# 4                                                109
#
#    INSULT_TO_MODESTY_OF_WOMEN  CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES  \
# 0                          34                                  175
# 1                          24                                  154
# 2                          83                                  186
# 3                          38                                   57
# 4                          58                                  247
#
#    IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES  CAUSING_DEATH_BY_NEGLIGENCE  \
# 0                                            0                          181
# 1                                            0                          270
# 2                                            0                          404
# 3                                            0                          233
# 4                                            0                          431
#
#    OTHER_IPC_CRIMES  TOTAL_IPC_CRIMES
# 0              1518              4154
# 1               754              4125
# 2              1262              5818
# 3              1181              3140
# 4              2313              6507
#
# [5 rows x 34 columns]

# %%
data.shape
# Out:
# (9017, 34)

# %%
data.TOTAL_IPC_CRIMES.value_counts()
# Out:
# 170      9
# 56       9
# 44       9
# 27       9
# 42       9
#         ..
# 34       1
# 4863     1
# 16168    1
# 7435     1
# 4281     1
# Name: TOTAL_IPC_CRIMES, Length: 5010, dtype: int64

# %% [markdown]
# #### TOTAL_IPC_CRIMES -- Target column .  It is the variable that the user would want to predict using the rest of the dataset.

# %% [markdown]
# # Cleaning Part

# %%
l=data["index"]
l
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 9012    9012
# 9013    9013
# 9014    9014
# 9015    9015
# 9016    9016
# Name: index, Length: 9017, dtype: int64

# %%
data=data.drop(["index"],axis=1)
data.head(2)
# Out:
#       STATE_or_UT   DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0  ANDHRA PRADESH   ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH  ANANTAPUR  2001     151                125
#
#    CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
#
#    OTHER_RAPE  KIDNAPPING_and_ABDUCTION  ...  ARSON  HURT_or_GREVIOUS_HURT  \
# 0          50                        46  ...     30                   1131
# 1          23                        53  ...     69                   1543
#
#    DOWRY_DEATHS  ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY  \
# 0            16                                                149
# 1             7                                                118
#
#    INSULT_TO_MODESTY_OF_WOMEN  CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES  \
# 0                          34                                  175
# 1                          24                                  154
#
#    IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES  CAUSING_DEATH_BY_NEGLIGENCE  \
# 0                                            0                          181
# 1                                            0                          270
#
#    OTHER_IPC_CRIMES  TOTAL_IPC_CRIMES
# 0              1518              4154
# 1               754              4125
#
# [2 rows x 33 columns]

# %% [markdown]
# # Missing Value Treatment

# %% [markdown]
# Missing values are usually represented in the form of Nan or null or None in the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9017 entries, 0 to 9016
# Data columns (total 33 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   STATE_or_UT                                          9017 non-null   object
#  1   DISTRICT                                             9017 non-null   object
#  2   YEAR                                                 9017 non-null   int64
#  3   MURDER                                               9017 non-null   int64
#  4   ATTEMPT_TO_MURDER                                    9017 non-null   int64
#  5   CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER            9017 non-null   int64
#  6   RAPE                                                 9017 non-null   int64
#  7   CUSTODIAL_RAPE                                       9017 non-null   int64
#  8   OTHER_RAPE                                           9017 non-null   int64
#  9   KIDNAPPING_and_ABDUCTION                             9017 non-null   int64
#  10  KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS          9017 non-null   int64
#  11  KIDNAPPING_AND_ABDUCTION_OF_OTHERS                   9017 non-null   int64
#  12  DACOITY                                              9017 non-null   int64
#  13  PREPARATION_AND_ASSEMBLY_FOR_DACOITY                 9017 non-null   int64
#  14  ROBBERY                                              9017 non-null   int64
#  15  BURGLARY                                             9017 non-null   int64
#  16  THEFT                                                9017 non-null   int64
#  17  AUTO_THEFT                                           9017 non-null   int64
#  18  OTHER_THEFT                                          9017 non-null   int64
#  19  RIOTS                                                9017 non-null   int64
#  20  CRIMINAL_BREACH_OF_TRUST                             9017 non-null   int64
#  21  CHEATING                                             9017 non-null   int64
#  22  COUNTERFIETING                                       9017 non-null   int64
#  23  ARSON                                                9017 non-null   int64
#  24  HURT_or_GREVIOUS_HURT                                9017 non-null   int64
#  25  DOWRY_DEATHS                                         9017 non-null   int64
#  26  ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY  9017 non-null   int64
#  27  INSULT_TO_MODESTY_OF_WOMEN                           9017 non-null   int64
#  28  CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                  9017 non-null   int64
#  29  IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES          9017 non-null   int64
#  30  CAUSING_DEATH_BY_NEGLIGENCE                          9017 non-null   int64
#  31  OTHER_IPC_CRIMES                                     9017 non-null   int64
#  32  TOTAL_IPC_CRIMES                                     9017 non-null   int64
# dtypes: int64(31), object(2)
# memory usage: 2.3+ MB

# %%
data.isnull().sum()
# Out:
# STATE_or_UT                                            0
# DISTRICT                                               0
# YEAR                                                   0
# MURDER                                                 0
# ATTEMPT_TO_MURDER                                      0
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER              0
# RAPE                                                   0
# CUSTODIAL_RAPE                                         0
# OTHER_RAPE                                             0
# KIDNAPPING_and_ABDUCTION                               0
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS            0
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                     0
# DACOITY                                                0
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                   0
# ROBBERY                                                0
# BURGLARY                                               0
# THEFT                                                  0
# AUTO_THEFT                                             0
# OTHER_THEFT                                            0
# RIOTS                                                  0
# CRIMINAL_BREACH_OF_TRUST                               0
# CHEATING                                               0
# COUNTERFIETING                                         0
# ARSON                                                  0
# HURT_or_GREVIOUS_HURT                                  0
# DOWRY_DEATHS                                           0
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY    0
# INSULT_TO_MODESTY_OF_WOMEN                             0
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                    0
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES            0
# CAUSING_DEATH_BY_NEGLIGENCE                            0
# OTHER_IPC_CRIMES                                       0
# TOTAL_IPC_CRIMES                                       0
# dtype: int64

# %% [markdown]
# # Data types Conversion

# %%
data.dtypes
# Out:
# STATE_or_UT                                            object
# DISTRICT                                               object
# YEAR                                                    int64
# MURDER                                                  int64
# ATTEMPT_TO_MURDER                                       int64
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER               int64
# RAPE                                                    int64
# CUSTODIAL_RAPE                                          int64
# OTHER_RAPE                                              int64
# KIDNAPPING_and_ABDUCTION                                int64
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS             int64
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                      int64
# DACOITY                                                 int64
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                    int64
# ROBBERY                                                 int64
# BURGLARY                                                int64
# THEFT                                                   int64
# AUTO_THEFT                                              int64
# OTHER_THEFT                                             int64
# RIOTS                                                   int64
# CRIMINAL_BREACH_OF_TRUST                                int64
# CHEATING                                                int64
# COUNTERFIETING                                          int64
# ARSON                                                   int64
# HURT_or_GREVIOUS_HURT                                   int64
# DOWRY_DEATHS                                            int64
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY     int64
# INSULT_TO_MODESTY_OF_WOMEN                              int64
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                     int64
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES             int64
# CAUSING_DEATH_BY_NEGLIGENCE                             int64
# OTHER_IPC_CRIMES                                        int64
# TOTAL_IPC_CRIMES                                        int64
# dtype: object

# %% [markdown]
# # Label Encoder

# %% [markdown]
# Label Encoding refers to converting the labels into a numeric form so as to convert them into the machine-readable form.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
data.STATE_or_UT=le.fit_transform(data.STATE_or_UT)

# %%
data.DISTRICT=le.fit_transform(data.DISTRICT)

# %%
data.STATE_or_UT.value_counts()
# Out:
# 32    878
# 19    628
# 20    552
# 4     540
# 30    469
# 28    454
# 25    430
# 16    399
# 11    384
# 1     370
# 3     362
# 14    322
# 27    314
# 15    312
# 34    309
# 12    268
# 6     266
# 17    233
# 2     195
# 9     183
# 13    176
# 33    168
# 24    138
# 21    125
# 23    108
# 22     96
# 31     67
# 29     60
# 0      36
# 8      36
# 10     36
# 26     31
# 5      24
# 7      24
# 18     24
# Name: STATE_or_UT, dtype: int64

# %%
data.DISTRICT.value_counts()
# Out:
# 753    408
# 240     46
# 706     37
# 547     37
# 801     36
#       ...
# 608      1
# 494      1
# 396      1
# 2        1
# 127      1
# Name: DISTRICT, Length: 808, dtype: int64

# %%
data.dtypes
# Out:
# STATE_or_UT                                            int32
# DISTRICT                                               int32
# YEAR                                                   int64
# MURDER                                                 int64
# ATTEMPT_TO_MURDER                                      int64
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER              int64
# RAPE                                                   int64
# CUSTODIAL_RAPE                                         int64
# OTHER_RAPE                                             int64
# KIDNAPPING_and_ABDUCTION                               int64
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS            int64
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                     int64
# DACOITY                                                int64
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                   int64
# ROBBERY                                                int64
# BURGLARY                                               int64
# THEFT                                                  int64
# AUTO_THEFT                                             int64
# OTHER_THEFT                                            int64
# RIOTS                                                  int64
# CRIMINAL_BREACH_OF_TRUST                               int64
# CHEATING                                               int64
# COUNTERFIETING                                         int64
# ARSON                                                  int64
# HURT_or_GREVIOUS_HURT                                  int64
# DOWRY_DEATHS                                           int64
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY    int64
# INSULT_TO_MODESTY_OF_WOMEN                             int64
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                    int64
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES            int64
# CAUSING_DEATH_BY_NEGLIGENCE                            int64
# OTHER_IPC_CRIMES                                       int64
# TOTAL_IPC_CRIMES                                       int64
# dtype: object

# %% [markdown]
# #  Exploratory Data Analysis(EDA)

# %% [markdown]
# ## Correlation

# %%
x=data.corr()
x
# Out:
#                                                     STATE_or_UT  DISTRICT  \
# STATE_or_UT                                            1.000000 -0.056215
# DISTRICT                                              -0.056215  1.000000
# YEAR                                                  -0.005635 -0.000987
# MURDER                                                -0.000691  0.166823
# ATTEMPT_TO_MURDER                                      0.028534  0.158203
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER              0.089772  0.092965
# RAPE                                                  -0.000655  0.172290
# CUSTODIAL_RAPE                                        -0.019203  0.038340
# OTHER_RAPE                                            -0.000644  0.172281
# KIDNAPPING_and_ABDUCTION                              -0.000786  0.136678
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS            0.020008  0.131440
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                    -0.058592  0.123673
# DACOITY                                               -0.067060  0.143096
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                   0.078200  0.081993
# ROBBERY                                                0.001106  0.151509
# BURGLARY                                              -0.038712  0.168435
# THEFT                                                 -0.009275  0.147329
# AUTO_THEFT                                            -0.004595  0.123194
# OTHER_THEFT                                           -0.011538  0.152441
# RIOTS                                                 -0.024211  0.156986
# CRIMINAL_BREACH_OF_TRUST                               0.004385  0.140200
# CHEATING                                               0.022635  0.130533
# COUNTERFIETING                                         0.004653  0.142584
# ARSON                                                 -0.053683  0.168466
# HURT_or_GREVIOUS_HURT                                 -0.042368  0.164499
# DOWRY_DEATHS                                           0.034559  0.118851
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MOD...    -0.008688  0.162718
# INSULT_TO_MODESTY_OF_WOMEN                            -0.024311  0.104936
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                    0.016545  0.133839
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRI
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MOD...          0.832525
# INSULT_TO_MODESTY_OF_WOMEN                                  0.473242
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                         0.692207
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES                 0.197713
# CAUSING_DEATH_BY_NEGLIGENCE                                 0.770637
# OTHER_IPC_CRIMES                                            1.000000
# TOTAL_IPC_CRIMES                                            0.951858
#
#                                                     TOTAL_IPC_CRIMES
# STATE_or_UT                                                -0.002005
# DISTRICT                                                    0.176049
# YEAR                                                        0.019805
# MURDER                                                      0.846449
# ATTEMPT_TO_MURDER                                           0.831710
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER                   0.519959
# RAPE                                                        0.858241
# CUSTODIAL_RAPE                                              0.126149
# OTHER_RAPE                                                  0.858237
# KIDNAPPING_and_ABDUCTION                                    0.751826
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS                 0.727661
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                          0.667329
# DACOITY                                                     0.636235
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                        0.462996
# ROBBERY                                                     0.842383
# BURGLARY                                                    0.904917
# THEFT                                                       0.910790
# AUTO_THEFT                                                  0.827573
# OTHER_THEFT                                                 0.901842
# RIOTS                                                       0.800871
# CRIMINAL_BREACH_OF_TRUST                                    0.774414
# CHEATING                                                    0.813745
# COUNTERFIETING                                              0.782653
# ARSON                                                       0.831871
# HURT_or_GREVIOUS_HURT                                       0.922862
# DOWRY_DEATHS                                                0.704394
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MOD...          0.890269
# INSULT_TO_MODESTY_OF_WOMEN                                  0.610444
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                         0.807875
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES                 0.202779
# CAUSING_DEATH_BY_NEGLIGENCE                                 0.872875
# OTHER_IPC_CRIMES                                            0.951858
# TOTAL_IPC_CRIMES                                            1.000000
#
# [33 rows x 33 columns]

# %%
plt.figure(figsize=(50,50))
heatmap=sns.heatmap(x,cmap="coolwarm",annot=True)
plt.title("Heatmap for correlation")
plt.show()

# %%
plt.figure(figsize=(20,9))
sns.boxplot(data=data)
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# # Creating Base Model

# %%
data.shape
# Out:
# (9017, 33)

# %%
x=data.iloc[:,0:-1]
y=data.iloc[:,-1]

# %%
x.shape,y.shape
# Out:
# ((9017, 32), (9017,))

# %% [markdown]
# ## Split Train and Test Data

# %%
import sklearn 
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((7213, 32), (1804, 32), (7213,), (1804,))

# %% [markdown]
# # Linear Regression

# %%
from sklearn import linear_model
lin=linear_model.LinearRegression()

# %%
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lin_p=lin.predict(x_test)
lin_p
# Out:
# array([7736.00019132,  957.99559738, 2391.00416086, ..., 2688.9995326 ,
#        2421.00211881,  792.00181661])

# %%
lin.coef_
# Out:
# array([-1.49919205e-04, -8.94792950e-06,  6.03399234e-04,  9.99985336e-01,
#         1.00000486e+00,  1.00003215e+00,  6.66733627e-01,  3.33463728e-01,
#         3.33269899e-01,  6.66669279e-01,  3.33336234e-01,  3.33333045e-01,
#         1.00002796e+00,  1.00002167e+00,  1.00000377e+00,  1.00000546e+00,
#         6.66665818e-01,  3.33333251e-01,  3.33332567e-01,  9.99996219e-01,
#         9.99990071e-01,  1.00000003e+00,  1.00004017e+00,  1.00000756e+00,
#         1.00000096e+00,  1.00001285e+00,  9.99991102e-01,  1.00000083e+00,
#         1.00000078e+00,  1.00004036e+00,  9.99998281e-01,  9.99999950e-01])

# %%
lin.intercept_
# Out:
# -1.2056443190422215

# %%
R2=lin.score(x_train,y_train)
R2
# Out:
# 0.9999999999648108

# %%
Adj_R2=1-(((1-R2)*(7213-1))/(7213-32-1))
Adj_R2
# Out:
# 0.9999999999646539

# %%
from sklearn import metrics

# %%
mse=metrics.mean_squared_error(y_test,lin_p)
mse
# Out:
# 0.044994246676763

# %%
rmse=pow(mse,0.5)
rmse
# Out:
# 0.21211847320957927

# %%
df1=pd.DataFrame({"Actual":y_test,"Predicted":lin_p})
df1
# Out:
#       Actual    Predicted
# 2899    7736  7736.000191
# 1598     958   957.995597
# 5258    2391  2391.004161
# 6050    2732  2732.004254
# 3881     543   542.999178
# ...      ...          ...
# 7149    1194  1194.003668
# 171     1855  1854.999720
# 6229    2689  2688.999533
# 8326    2421  2421.002119
# 7942     792   792.001817
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=df1,fit_reg=False)
d_line=np.arange(df1.min().min(),df1.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # Lasso(L1)

# %% [markdown]
# Lasso is used to sove the probem of underfitting ,feature selection

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()

# %%
lasso.fit(x_train,y_train)
# Out:
# Lasso()

# %%
l_p=lasso.predict(x_test)
l_p
# Out:
# array([7736.15164425,  958.11340693, 2390.92246064, ..., 2689.01905248,
#        2421.24629432,  791.99359121])

# %%
lasso.coef_    #feature selection
# Out:
# array([-0.00000000e+00,  3.37313054e-05,  0.00000000e+00,  1.00268470e+00,
#         1.00046026e+00,  9.93489311e-01,  1.00001485e+00, -0.00000000e+00,
#         1.52530003e-03,  9.96160007e-01,  1.68064748e-03,  5.48145681e-03,
#         9.95759585e-01,  1.00020507e+00,  9.99950102e-01,  9.99326560e-01,
#         1.00000060e+00,  1.55501094e-05,  1.02989394e-04,  1.00041638e+00,
#         1.00232718e+00,  1.00000228e+00,  9.90231361e-01,  9.99301040e-01,
#         9.99944508e-01,  9.98608297e-01,  9.99925474e-01,  9.99450382e-01,
#         1.00001964e+00,  7.14307799e-01,  1.00012419e+00,  1.00000200e+00])

# %%
l_R2=lasso.score(x_train,y_train)
l_R2
# Out:
# 0.9999999989912085

# %%
l_Adj_R2=1-(((1-l_R2)*(7213-1))/(7213-32-1))
l_Adj_R2
# Out:
# 0.9999999989867125

# %%
l_mse=metrics.mean_squared_error(y_test,l_p)
l_mse
# Out:
# 0.610237083614304

# %%
l_df=pd.DataFrame({"Importances":list(lasso.coef_),"column":list(x_test)})
l_df
# Out:
#     Importances                                             column
# 0     -0.000000                                        STATE_or_UT
# 1      0.000034                                           DISTRICT
# 2      0.000000                                               YEAR
# 3      1.002685                                             MURDER
# 4      1.000460                                  ATTEMPT_TO_MURDER
# 5      0.993489          CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER
# 6      1.000015                                               RAPE
# 7     -0.000000                                     CUSTODIAL_RAPE
# 8      0.001525                                         OTHER_RAPE
# 9      0.996160                           KIDNAPPING_and_ABDUCTION
# 10     0.001681        KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS
# 11     0.005481                 KIDNAPPING_AND_ABDUCTION_OF_OTHERS
# 12     0.995760                                            DACOITY
# 13     1.000205               PREPARATION_AND_ASSEMBLY_FOR_DACOITY
# 14     0.999950                                            ROBBERY
# 15     0.999327                                           BURGLARY
# 16     1.000001                                              THEFT
# 17     0.000016                                         AUTO_THEFT
# 18     0.000103                                        OTHER_THEFT
# 19     1.000416                                              RIOTS
# 20     1.002327                           CRIMINAL_BREACH_OF_TRUST
# 21     1.000002                                           CHEATING
# 22     0.990231                                     COUNTERFIETING
# 23     0.999301                                              ARSON
# 24     0.999945                              HURT_or_GREVIOUS_HURT
# 25     0.998608                                       DOWRY_DEATHS
# 26     0.999925  ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MO...
# 27     0.999450                         INSULT_TO_MODESTY_OF_WOMEN
# 28     1.000020                CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES
# 29     0.714308        IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES
# 30     1.000124                        CAUSING_DEATH_BY_NEGLIGENCE
# 31     1.000002                                   OTHER_IPC_CRIMES

# %%
n_df=data.drop(["STATE_or_UT","YEAR","CUSTODIAL_RAPE"],axis=1)
n_df
# Out:
#       DISTRICT  MURDER  ATTEMPT_TO_MURDER  \
# 0            3     101                 60
# 1           28     151                125
# 2          154     101                 57
# 3          172      80                 53
# 4          220      82                 67
# ...        ...     ...                ...
# 9012       453       0                  0
# 9013       753       0                  0
# 9014       382       5                  6
# 9015       589      24                 21
# 9016       753      29                 27
#
#       CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  OTHER_RAPE  \
# 0                                            17    50          50
# 1                                             1    23          23
# 2                                             2    27          27
# 3                                             1    20          20
# 4                                             1    23          23
# ...                                         ...   ...         ...
# 9012                                          0     0           0
# 9013                                          0     0           0
# 9014                                          2     6           6
# 9015                                         10     7           7
# 9016                                         12    13          13
#
#       KIDNAPPING_and_ABDUCTION  KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS  \
# 0                           46                                           30
# 1                           53                                           30
# 2                           59                                           34
# 3                           25                                           20
# 4                           49                                           26
# ...                        ...                                          ...
# 9012                         0                                            0
# 9013                         0                                            0
# 9014                         2                                            2
# 9015                        17                                           14
# 9016                        19                                           16
#
#       KIDNAPPING_AND_ABDUCTION_OF_OTHERS  DACOITY  ...  ARSON  \
# 0                                     16        9  ...     30
# 1                                     23        8  ...     69
# 2                                     25        4  ...     38
# 3                                      5        1  ...     23
# 4                                     23        4  ...     41
# ...                                  ...      ...  ...    ...
# 9012                                   0        0  ...      3
# 9013                                   0        0  ...      3
# 9014                                   0        0  ...      1
# 9015                                   3        5  ...     20
# 9016                                   3        5  ...     21
#
#       HURT_or_GREVIOUS_HURT  DOWRY_DEATHS  \
# 0                      1131            16
# 1                      1543             7
# 2                      2088            14
# 3                       795            17
# 4                      1244            12
# ...                     ...           ...
# 9012                      3             0
# 9013                      3             0
# 9014                    186             0
# 9015                    632             0
# 9016                    818             0
#
#       ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY  \
# 0                                                   149
# 1                                                   118
# 2                                                   112
# 3                                                   126
# 4                                                   109
# ...                                                 ...
# 9012                                                  1
# 9013                                                  1
# 9014                                                  2
# 9015                                                  7
# 9016                                                  9
#
#       INSULT_TO_MODESTY_OF_WOMEN  CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES  \
# 0                             34                                  175
# 1                             24                                  154
# 2                             83                                  186
# 3                             38                                   57
# 4                             58                                  247
# ...                          ...                                  ...
# 9012                           0                                    1
# 9013                           0                                    1
# 9014                           0                                    1
# 9015                           2                                    5
# 9016                           2                                    6
#
#       IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 9012                                            0
# 9013                                            0
# 9014                                            0
# 9015                                            0
# 9016                                            0
#
#       CAUSING_DEATH_BY_NEGLIGENCE  OTHER_IPC_CRIMES  TOTAL_IPC_CRIMES
# 0                             181              1518              4154
# 1                             270               754              4125
# 2                             404              1262              5818
# 3                             233              1181              3140
# 4                             431              2313              6507
# ...                           ...               ...               ...
# 9012                            0                32                60
# 9013                            0                32                60
# 9014                           44               392               787
# 9015                          219              1668              3494
# 9016                          263              2060              4281
#
# [9017 rows x 30 columns]

# %%
n_x=n_df.iloc[:,0:-1]
n_y=n_df.iloc[:,-1]

# %%
nx_train,nx_test,ny_train,ny_test=train_test_split(n_x,n_y,test_size=0.2,random_state=101)

# %%
nx_train.shape,nx_test.shape,ny_train.shape,ny_test.shape
# Out:
# ((7213, 29), (1804, 29), (7213,), (1804,))

# %%
lin.fit(nx_train,ny_train)
# Out:
# LinearRegression()

# %%
n_p=lin.predict(nx_test)

# %%
n_R2=lin.score(nx_train,ny_train)
n_R2
# Out:
# 0.999999999937231

# %%
n_Adj_R2=1-(((1-n_R2)*(7213-1))/(7213-29-1))
n_Adj_R2
# Out:
# 0.9999999999369775

# %%
n_mse=metrics.mean_squared_error(ny_test,n_p)
n_mse
# Out:
# 3.905364155946777e-06

# %%
n_df1=pd.DataFrame({"Actual_n":ny_test,"Predicted_n":n_p})
n_df1
# Out:
#       Actual_n  Predicted_n
# 8741      3065  3065.001687
# 4584      1336  1336.000824
# 5420      8008  8007.999305
# 8808        31    30.999398
# 1881       976   975.999035
# ...        ...          ...
# 1465       145   145.001389
# 2198       180   179.999835
# 5753      1059  1059.002261
# 1564       869   869.000154
# 2199       440   439.999436
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual_n",y="Predicted_n",data=n_df1,fit_reg=False)
d_line=np.arange(n_df1.min().min(),n_df1.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # Ridge(L2)

# %% [markdown]
# #### Ridge regression is mostly used to reduce the overfitting in the model

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge()

# %%
r_p=ridge.predict(x_test)

# %%
list(ridge.coef_)
# Out:
# [-0.00014967589315763533,
#  -8.925899313070014e-06,
#  0.0006038190735991425,
#  0.9999857150559557,
#  1.0000047546679165,
#  1.0000303918000808,
#  0.6656734762388798,
#  0.33135505371854207,
#  0.33433091847532476,
#  0.6666889998159794,
#  0.3333168399474369,
#  0.33331381125773457,
#  1.0000285892674865,
#  1.0000222414149549,
#  1.0000038617559892,
#  1.0000054730640318,
#  0.666669842584811,
#  0.3333291380354977,
#  0.33332854056941813,
#  0.9999962497904666,
#  0.9999904162678339,
#  1.0000000265090474,
#  1.000037838648442,
#  1.0000068356953313,
#  1.0000010060118498,
#  1.0000122278504586,
#  0.9999906512947965,
#  1.0000010524656215,
#  1.000000704692925,
#  0.9999889073181898,
#  0.9999982568025415,
#  0.9999999503113078]

# %%
r_df=pd.DataFrame({"Coef":list(ridge.coef_),"col":list(x_test)})
r_df
# Out:
#         Coef                                                col
# 0  -0.000150                                        STATE_or_UT
# 1  -0.000009                                           DISTRICT
# 2   0.000604                                               YEAR
# 3   0.999986                                             MURDER
# 4   1.000005                                  ATTEMPT_TO_MURDER
# 5   1.000030          CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER
# 6   0.665673                                               RAPE
# 7   0.331355                                     CUSTODIAL_RAPE
# 8   0.334331                                         OTHER_RAPE
# 9   0.666689                           KIDNAPPING_and_ABDUCTION
# 10  0.333317        KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS
# 11  0.333314                 KIDNAPPING_AND_ABDUCTION_OF_OTHERS
# 12  1.000029                                            DACOITY
# 13  1.000022               PREPARATION_AND_ASSEMBLY_FOR_DACOITY
# 14  1.000004                                            ROBBERY
# 15  1.000005                                           BURGLARY
# 16  0.666670                                              THEFT
# 17  0.333329                                         AUTO_THEFT
# 18  0.333329                                        OTHER_THEFT
# 19  0.999996                                              RIOTS
# 20  0.999990                           CRIMINAL_BREACH_OF_TRUST
# 21  1.000000                                           CHEATING
# 22  1.000038                                     COUNTERFIETING
# 23  1.000007                                              ARSON
# 24  1.000001                              HURT_or_GREVIOUS_HURT
# 25  1.000012                                       DOWRY_DEATHS
# 26  0.999991  ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MO...
# 27  1.000001                         INSULT_TO_MODESTY_OF_WOMEN
# 28  1.000001                CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES
# 29  0.999989        IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES
# 30  0.999998                        CAUSING_DEATH_BY_NEGLIGENCE
# 31  1.000000                                   OTHER_IPC_CRIMES

# %%
r_R2=ridge.score(x_train,y_train)
r_R2
# Out:
# 0.9999999999648104

# %%
r_AdR2=1-(((1-r_R2)*(7213-1))/(7213-32-1))
r_AdR2
# Out:
# 0.9999999999646535

# %%
r_mse=metrics.mean_squared_error(y_test,r_p)
r_mse
# Out:
# 0.044994284078450374

# %% [markdown]
# # Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()

# %%
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr_p=rfr.predict(x_test)

# %%
rf_rsq=rfr.score(x_train,y_train)
rf_rsq
# Out:
# 0.9990616449746009

# %%
rf_adr=1-(((1-rf_rsq)*(7213-1))/(7213-32-1))
rf_adr
# Out:
# 0.9990574628909222

# %%
rfr_MSE=metrics.mean_squared_error(y_test,rfr_p)
rfr_MSE
# Out:
# 2469658.45352489

# %%
rf_df=pd.DataFrame({"Actual":y_test,"Predicted":rfr_p})
rf_df
# Out:
#       Actual  Predicted
# 2899    7736    8009.61
# 1598     958     981.17
# 5258    2391    2348.16
# 6050    2732    2756.48
# 3881     543     566.33
# ...      ...        ...
# 7149    1194    1147.68
# 171     1855    1879.27
# 6229    2689    2744.03
# 8326    2421    2275.21
# 7942     792     825.18
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=rf_df,fit_reg=False)
d_line=np.arange(rf_df.min().min(),rf_df.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # Boosting

# %% [markdown]
# ## 1.XG-Boost Regressor

# %% [markdown]
# ###  advantages of XGBoost is its ability to handle missing data

# %%
from xgboost import XGBRFRegressor
xgb=XGBRFRegressor()

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
#                reg_alpha=None, ...)

# %%
xg_p=xgb.predict(x_test)

# %%
xg_rsq=xgb.score(x_train,y_train)
xg_rsq
# Out:
# 0.9983490259391863

# %%
xg_adr=1-(((1-xg_rsq)*(7213-1))/(7213-32-1))
xg_adr
# Out:
# 0.9983416678375225

# %%
xg_mse=metrics.mean_squared_error(y_test,xg_p)
xg_mse
# Out:
# 2489242.5667013647

# %%
xg_df=pd.DataFrame({"Actual":y_test,"Predicted":xg_p})
xg_df
# Out:
#       Actual    Predicted
# 2899    7736  6969.096191
# 1598     958  1283.411499
# 5258    2391  2440.406738
# 6050    2732  2614.605957
# 3881     543   749.363525
# ...      ...          ...
# 7149    1194  1189.102295
# 171     1855  2120.077881
# 6229    2689  2629.222900
# 8326    2421  2181.483887
# 7942     792   906.949829
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=xg_df,fit_reg=False)
d_line=np.arange(xg_df.min().min(),xg_df.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# ## AdaBoostRegressor

# %%
# A boosting gives high accuracy. Missclassification

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor()

# %%
ad.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
ad_p=ad.predict(x_test)

# %%
ad_rsq=ad.score(x_train,y_train)
ad_rsq
# Out:
# 0.9572919740118131

# %%
ad_adr=1-(((1-ad_rsq)*(7213-1))/(7213-32-1))
ad_adr
# Out:
# 0.957101631834707

# %%
ad_MSE=metrics.mean_squared_error(y_test,ad_p)
ad_MSE
# Out:
# 15084603.889698766

# %% [markdown]
# # Final result before EDA

# %%
l1=["Linear Regression","Random Forest Regressor","XG-Boost Regressor","AdaBoostRegressor"]
l2=[R2,rf_rsq,xg_rsq,ad_rsq]
l3=[Adj_R2,rf_adr,xg_adr,ad_adr]
l4=[mse,rfr_MSE,xg_mse,ad_MSE]

# %%
before_eda=pd.DataFrame({"Model_Name":l1,"R-square":l2,"Adj_R2":l3,"MSE":l4})
before_eda
# Out:
#                 Model_Name  R-square    Adj_R2           MSE
# 0        Linear Regression  1.000000  1.000000  4.499425e-02
# 1  Random Forest Regressor  0.999062  0.999057  2.469658e+06
# 2       XG-Boost Regressor  0.998349  0.998342  2.489243e+06
# 3        AdaBoostRegressor  0.957292  0.957102  1.508460e+07

# %% [markdown]
# # Model building after EDA

# %%
plt.figure(figsize=(20,9))
sns.boxplot(data=data)
plt.xticks(rotation=70)
plt.show()

# %%
data.hist(figsize=(15,10),xrot=45)
plt.xticks(rotation=70)
plt.show()

# %%
data.dtypes
# Out:
# STATE_or_UT                                            int32
# DISTRICT                                               int32
# YEAR                                                   int64
# MURDER                                                 int64
# ATTEMPT_TO_MURDER                                      int64
# CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER              int64
# RAPE                                                   int64
# CUSTODIAL_RAPE                                         int64
# OTHER_RAPE                                             int64
# KIDNAPPING_and_ABDUCTION                               int64
# KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS            int64
# KIDNAPPING_AND_ABDUCTION_OF_OTHERS                     int64
# DACOITY                                                int64
# PREPARATION_AND_ASSEMBLY_FOR_DACOITY                   int64
# ROBBERY                                                int64
# BURGLARY                                               int64
# THEFT                                                  int64
# AUTO_THEFT                                             int64
# OTHER_THEFT                                            int64
# RIOTS                                                  int64
# CRIMINAL_BREACH_OF_TRUST                               int64
# CHEATING                                               int64
# COUNTERFIETING                                         int64
# ARSON                                                  int64
# HURT_or_GREVIOUS_HURT                                  int64
# DOWRY_DEATHS                                           int64
# ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY    int64
# INSULT_TO_MODESTY_OF_WOMEN                             int64
# CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES                    int64
# IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES            int64
# CAUSING_DEATH_BY_NEGLIGENCE                            int64
# OTHER_IPC_CRIMES                                       int64
# TOTAL_IPC_CRIMES                                       int64
# dtype: object

# %%
#TOTAL_IPC_CRIMES

# %%
#OTHER_IPC_CRIMES

# %%
sns.histplot(data.OTHER_IPC_CRIMES)
# Out:
# <AxesSubplot:xlabel='OTHER_IPC_CRIMES', ylabel='Count'>

# %%
sns.distplot(data.OTHER_IPC_CRIMES)
# Out:
# <AxesSubplot:xlabel='OTHER_IPC_CRIMES', ylabel='Density'>

# %%
sns.boxplot(data=data,y='OTHER_IPC_CRIMES')
plt.show()

# %%
data.OTHER_IPC_CRIMES.describe()
# Out:
# count      9017.000000
# mean       2174.299434
# std        7988.438462
# min           0.000000
# 25%         265.000000
# 50%         745.000000
# 75%        1608.000000
# max      124176.000000
# Name: OTHER_IPC_CRIMES, dtype: float64

# %%
iqr=data.OTHER_IPC_CRIMES.quantile(0.75)-data.OTHER_IPC_CRIMES.quantile(0.25)
iqr
# Out:
# 1343.0

# %%
ub=data['OTHER_IPC_CRIMES'].quantile(0.75)+(iqr*3)
lb=data['OTHER_IPC_CRIMES'].quantile(0.25)-(iqr*3)
print(lb,ub)
# Out:
# -3764.0 5637.0

# %%
data.loc[data['OTHER_IPC_CRIMES']>ub,'OTHER_IPC_CRIMES']=ub
data.loc[data['OTHER_IPC_CRIMES']<lb,'OTHER_IPC_CRIMES']=lb

# %%
sns.distplot(data.OTHER_IPC_CRIMES)
# Out:
# <AxesSubplot:xlabel='OTHER_IPC_CRIMES', ylabel='Density'>

# %% [markdown]
# # Creating Model after EDA

# %%
Total_IPC_Crimes=data["TOTAL_IPC_CRIMES"]
Total_IPC_Crimes
# Out:
# 0       4154
# 1       4125
# 2       5818
# 3       3140
# 4       6507
#         ...
# 9012      60
# 9013      60
# 9014     787
# 9015    3494
# 9016    4281
# Name: TOTAL_IPC_CRIMES, Length: 9017, dtype: int64

# %%
df=data.drop(['TOTAL_IPC_CRIMES'],axis=1)
df.head(2)
# Out:
#    STATE_or_UT  DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0            1         3  2001     101                 60
# 1            1        28  2001     151                125
#
#    CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
#
#    OTHER_RAPE  KIDNAPPING_and_ABDUCTION  ...  COUNTERFIETING  ARSON  \
# 0          50                        46  ...               1     30
# 1          23                        53  ...               8     69
#
#    HURT_or_GREVIOUS_HURT  DOWRY_DEATHS  \
# 0                   1131            16
# 1                   1543             7
#
#    ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY  \
# 0                                                149
# 1                                                118
#
#    INSULT_TO_MODESTY_OF_WOMEN  CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES  \
# 0                          34                                  175
# 1                          24                                  154
#
#    IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES  CAUSING_DEATH_BY_NEGLIGENCE  \
# 0                                            0                          181
# 1                                            0                          270
#
#    OTHER_IPC_CRIMES
# 0              1518
# 1               754
#
# [2 rows x 32 columns]

# %%
e_x=df
e_y=Total_IPC_Crimes

# %% [markdown]
# # Splitting train and test

# %%
ex_train,ex_test,ey_train,ey_test=train_test_split(e_x,e_y,test_size=0.2,random_state=100)

# %%
ex_train.shape,ex_test.shape,ey_train.shape,ey_test.shape
# Out:
# ((7213, 32), (1804, 32), (7213,), (1804,))

# %% [markdown]
# # Linear Regression

# %%
lin.fit(ex_train,ey_train)
# Out:
# LinearRegression()

# %%
lin_p1=lin.predict(ex_test)
lin_p1
# Out:
# array([7070.78386247, 1485.03386247, 2328.28386247, ..., 3644.78386247,
#        4831.78386247,  390.28386247])

# %%
e_R2=lin.score(ex_train,ey_train)
e_R2
# Out:
# 0.9796950890875904

# %%
e_adjR2=1-(((1-e_R2)*(7213-1))/(7213-32-1))
e_adjR2
# Out:
# 0.9796045936629112

# %%
e_mse=metrics.mean_squared_error(ey_test,lin_p1)
e_mse
# Out:
# 13542527.08543887

# %%
e_rmse=pow(e_mse,0.5)
e_rmse
# Out:
# 3680.017267002815

# %%
df2=pd.DataFrame({"Actual":ey_test,"Predicted":lin_p1})
df2
# Out:
#       Actual    Predicted
# 2899    7736  7070.783862
# 1598     958  1485.033862
# 5258    2391  2328.283862
# 6050    2732  2462.783862
# 3881     543  -466.419263
# ...      ...          ...
# 7149    1194  1120.533862
# 171     1855  1587.783862
# 6229    2689  3644.783862
# 8326    2421  4831.783862
# 7942     792   390.283862
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=df2,fit_reg=False)
d_line=np.arange(df2.min().min(),df2.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # XG boost

# %%
from xgboost import XGBRFRegressor
xg1=XGBRFRegressor()

# %%
xg1.fit(ex_train,ey_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
#                reg_alpha=None, ...)

# %%
xg1_p=xg1.predict(ex_test)

# %%
R_xg1=xg1.score(ex_train,ey_train)
R_xg1
# Out:
# 0.9979339011286679

# %%
Adj_xg1=1-(((1-R_xg1)*(7213-1))/(7213-32-1))
Adj_xg1
# Out:
# 0.9979246928885728

# %%
xg1_mse=metrics.mean_squared_error(ey_test,xg1_p)
xg1_mse
# Out:
# 5013202.996779209

# %%
xg1_df=pd.DataFrame({"Actual":ey_test,"Predicted":xg1_p})
xg1_df
# Out:
#       Actual    Predicted
# 2899    7736  6968.060059
# 1598     958  1301.377319
# 5258    2391  2481.146729
# 6050    2732  2635.399902
# 3881     543   747.374817
# ...      ...          ...
# 7149    1194  1207.684448
# 171     1855  2141.512207
# 6229    2689  2615.870850
# 8326    2421  2172.482178
# 7942     792   892.679993
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=xg1_df,fit_reg=False)
d_line=np.arange(xg1_df.min().min(),xg1_df.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr1=RandomForestRegressor()

# %%
rfr1.fit(ex_train,ey_train)
# Out:
# RandomForestRegressor()

# %%
rfr1_p=rfr1.predict(ex_test)

# %%
R_rf1=rfr1.score(ex_train,ey_train)
R_rf1
# Out:
# 0.9987063952759306

# %%
Adj_rf1=1-(((1-R_rf1)*(7213-1))/(7213-32-1))
Adj_rf1
# Out:
# 0.9987006299066868

# %%
Rf_mse1=metrics.mean_squared_error(ey_test,rfr1_p)
Rf_mse1
# Out:
# 4149252.1716516083

# %%
Rf_df=pd.DataFrame({"Actual":ey_test,"Predicted":rfr1_p})
Rf_df
# Out:
#       Actual  Predicted
# 2899    7736    7892.63
# 1598     958     957.16
# 5258    2391    2403.50
# 6050    2732    2783.23
# 3881     543     564.34
# ...      ...        ...
# 7149    1194    1134.52
# 171     1855    1860.75
# 6229    2689    2747.89
# 8326    2421    2296.11
# 7942     792     823.10
#
# [1804 rows x 2 columns]

# %%
sns.lmplot(x="Actual",y="Predicted",data=Rf_df,fit_reg=False)
d_line=np.arange(Rf_df.min().min(),Rf_df.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.show()

# %% [markdown]
# # After EDA Final result

# %%
list5=["RandomForestRegressor","LinearRegression","XGBRFRegressor"]
list6=[R_rf1,e_R2,R_xg1]
list7=[Adj_rf1,e_adjR2,Adj_xg1]
list8=[Rf_mse1,e_mse,xg1_mse]

# %%
after_eda=pd.DataFrame({"Model_Name":list5,"R-square":list6,"Adj_R2":list7,"MSE":list8})
after_eda
# Out:
#               Model_Name  R-square    Adj_R2           MSE
# 0  RandomForestRegressor  0.998706  0.998701  4.149252e+06
# 1       LinearRegression  0.979695  0.979605  1.354253e+07
# 2         XGBRFRegressor  0.997934  0.997925  5.013203e+06

# %%
before_eda
# Out:
#                 Model_Name  R-square    Adj_R2           MSE
# 0        Linear Regression  1.000000  1.000000  4.499425e-02
# 1  Random Forest Regressor  0.999062  0.999057  2.469658e+06
# 2       XG-Boost Regressor  0.998349  0.998342  2.489243e+06
# 3        AdaBoostRegressor  0.957292  0.957102  1.508460e+07

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Linear Regression is best fitted model.

# %%
sns.lmplot(x="Actual",y="Predicted",data=df1,fit_reg=False)
d_line=np.arange(df1.min().min(),df1.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.title("before_eda")
plt.show()
sns.lmplot(x="Actual",y="Predicted",data=df2,fit_reg=False)
d_line=np.arange(df2.min().min(),df2.max().max())
plt.plot(d_line,d_line,color="green",linestyle="-")
plt.title("after_eda")
plt.show()
